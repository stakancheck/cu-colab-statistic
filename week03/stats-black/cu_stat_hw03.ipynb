# %% [markdown]
# # Задача 1. Построй гистограмму, boxplot

# %% [markdown]
# Датасет [golden_mine.csv](https://raw.githubusercontent.com/zalig/cu-datasets/main/golden_mine.csv) содержит данные для кейса [«Золотая жила»](https://raw.githubusercontent.com/zalig/cu-datasets/main/case_1_golden_mine.pdf), в котором нужно с помощью датасета найти наиболее прибыльные категории клиентов — пользователей
# платформы для изучения иностранного языка.
#
# Это задание позволяет познакомиться с датасетом и провести некоторые расчёты в нём.
#
# Целиком решать кейс пока не требуется.
#
# Описание столбцов датасета:
#
# - Gender – пол клиента;
# - Age — возраст клиента в годах;
# - Age Group — возрастная группа;
# - Payments — общая сумма платежей от игрока в рублях за всё время существования платформы;
# - Costs — себестоимость оказанных клиенту услуг в рублях за всё время существования платформы;
# - Profit — разница между Payments и Costs.

# %% [markdown]
# Построй графики и прокомментируй их. Главное требование к каждому графику — он должен быть читаемым и понятным сам по себе, без окружающего текста.
#
# ##1. (blue, баллы: 3.5) Построй гистограммы прибыли с клиента для двух категорий:
#   - «Мужчины 18–24 лет».
#   - «Женщины 18–24 лет».
#
#   Какие выводы можно сделать из графиков?
#
# ##2. (blue, баллы: 3.5) Построй boxplot (он же график «ящик с усами») прибыли  с клиента для двух категорий:
#   - «Мужчины 18–24 лет».
#   - «Женщины 18–24 лет».
#
#   Какие выводы можно сделать из графиков?
#
# ##3. (red, баллы: 2) Опираясь на данную изначально разбивку на возрастные группы, проведи очистку данных для каждой категории, сочетающей пол и возрастную группу. Затем для каждой категории построй:
#   - boxplot'ы прибыли — на одном графике для сопоставления;
#   - гистограммы прибыли — на одном графике для сопоставления.
#
#   Какие выводы можно сделать из графиков?

# %% [markdown]
# # Задача 2. Проинтерпретируй графики «из  интернета» как получится

# %% [markdown]
# Какие выводы можно сделать из каждого графика ниже? Простых интерпретаций будет достаточно, но всё же содержательные выводы ценятся выше.

# %% [markdown]
# ## 1. (blue, баллы: 3)

# %% [markdown]
#   ![hw3_2_blue.png](data:image/png;base64,...)

# %% [markdown]
# Источник: https://telegra.ph/Mogut-li-vodyanye-batarei-reshit-problemu-hraneniya-ehnergii-01-10.

# %% [markdown]
# ##2. (black, баллы: 5)

# %% [markdown]
#   ![hw3_2_black.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Источник: https://telegra.ph/Dejstvitelno-li-Velikobritaniya-tak-zhe-bedna-kak-Missisipi-08-11.

# %% [markdown]
# # Задача 3. Проверь, как меняется график при изменении данных, и найди статистики по графику

# %% [markdown]
# ## 1. (red, баллы: 3) Дан произвольный boxplot (перев. «ящик с усами»), построенный по $n$ наблюдениям.
#
# Как он изменится, если все значения, которые больше первого квартиля, но меньше медианы, заменить на первый квартиль? А если заменить на медиану? Для исключения граничных случаев дано, что $n-1$ делится на 4 нацело. Для простоты считай, что в выборке нет выбросов.

# %% [markdown]
# ## 2. (black, баллы: 5) Для столбчатой диаграммы (barchart) ниже определи, каким бы мог быть средний чек: найди все возможные значения. Данные должны соответствовать гистограмме!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Кейс «Золотая жила»
#
# ## Реши кейс [«Золотая жила»](https://github.com/zalig/cu-datasets/raw/main/case_1_golden_mine.pdf) на соответствующем уровне.
#
# Кейс не считается одной из задач домашнего задания и проверяется отдельно.

# %% [markdown]
# # Кейсы «Рекламщики» и «Экспансия»
#
# ##(black) Реши кейс [«Рекламщики»](https://github.com/zalig/cu-datasets/raw/main/case_2_ad.pdf) или [«Экспансия»](https://github.com/zalig/cu-datasets/raw/main/case_3_exp.pdf), если проходишь курс на чёрном уровне.
#
# Кейс не считается одной из задач домашнего задания и проверяется отдельно.
