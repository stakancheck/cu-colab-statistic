# %% [markdown]
# # Проект №1
# **Разведывательный анализ данных на примере датасета "Stack Overflow Annual Developer Survey"**
#
# В рамках IT-сферы существует огромное количество специалистов, задействованных в различных областях — от разработки ПО до управления проектами и анализа данных. Stack Overflow ежегодно проводит глобальное исследование среди разработчиков, чтобы понять их профессиональные предпочтения, используемые технологии, уровень заработной платы и многие другие аспекты. Эти данные предоставляют ценную информацию как для специалистов, так и для компаний, нанимающих IT-таланты.
#
# Твоей задачей будет провести разведывательный анализ данных, предоставленных Stack Overflow за 2023 год. Анализ поможет выявить ключевые тенденции, скрытые закономерности и проблемы в данных, такие как пропущенные значения или ошибки в структуре данных.
#
# **Цель**: на основе данных ежегодного опроса разработчиков Stack Overflow (за 2023 год) глубже понять, какие факторы влияют на карьерный рост в IT, уровень заработной платы, предпочтения в технологиях и другие аспекты, интересующие как самих разработчиков, так и компании.
#
# **Основные задачи проекта:**
# - Познакомиться со структурой датасета и типами данных.
# - Применить основные навыки работы с данными на Python (агрегация, фильтрация, визуализация).
# - Проанализировать пропущенные значения и выявить потенциальные проблемы в данных.
# - Выявить закономерности и визуализировать ключевые атрибуты для постановки гипотез.
# - Развить навыки интерпретации данных и формулирования гипотез, которые могут быть полезны для бизнеса.

# %% [markdown]
# Анализ проводится на датасете `'Stack Overflow Annual Developer Survey'`. Эти данные представляют собой результаты ежегодного опроса представителей разных профессий в сфере информационных технологий (IT).
#
# Тематически данные делятся на семь блоков:
# 1. Базовая информация
# 2. Образование, работа и карьера
# 3. Технологии и культура в IT (tech culture)
# 4. Использование Stack Overflow и сообщество
# 5. Искусственный интеллект (AI)
# 6. Группа вопросов для профессиональных разработчиков (опциональный блок)
# 7. Заключительные вопросы
#
# *Источник данных: [Stack Overflow](https://survey.stackoverflow.co/)*
#
# *Подробнее о методологии и данных можно также почитать [тут](https://survey.stackoverflow.co/2023/).*

# %% [markdown]
# # Формат сдачи проекта
#
# Аналитики данных не только находят инсайты, но и умеют их доносить. Правильное оформление ноутбука — это твой инструмент, чтобы идеи и результаты были понятны другим, будь то коллеги, заказчики или даже ты сам через пару месяцев.
# Поэтому оформи проект в отдельном ноутбуке и используй эти принципы:
#
# 1. **Заголовки**: четко разделяй проект на логичные блоки с помощью заголовков. Это поможет легко ориентироваться в содержании и понимать, о чем каждый раздел.
#
# 2. **Описание**: перед каждым блоком кода добавляй краткое описание, которое объясняет, что ты собираешься сделать и зачем это нужно. Это помогает лучше понять ход анализа.
#
# 3. **Комментарии к коду**: всегда добавляй комментарии к коду. Это позволит любому человеку, включая тебя самого в будущем, быстро понять, что делает каждая строка или блок кода.
#
# 4. **Выводы**: не забудь выделить раздел для выводов. Здесь нужно кратко описать ключевые инсайты и результаты, которые ты нашел в ходе анализа. Это поможет закрепить основные моменты и подвести итоги работы.

# %% [markdown]
# # Оценивание проекта
#
# Проект оценивается экспертом (преподавателем) на основе заранее заданных критериев, которые указаны под каждым заданием.
#
# <!-- Баллы за выполнение всех заданий суммируются, и на основе общей суммы выставляется итоговая оценка по **10-балльной** шкале. -->
#
# Баллы за выполнение всех заданий суммируются, и конвертируются в итоговую оценку по **10-балльной** шкале.
#
# Максимальное количество баллов за проект - **100 баллов**
#
# Таблица конвертации 100-бальной оценки в 10-бальную шкалу:
#
# | Баллы | Оценка |
# |----------------------------|---------------------------|
# | 91-100                      | 10                        |
# | 81-90                       | 9                         |
# | 71-80                       | 8                         |
# | 61-70                       | 7                         |
# | 51-60                       | 6                         |
# | 41-50                       | 5                         |
# | 31-40                       | 4                         |
# | 21-30                       | 3                         |
# | 11-20                       | 2                         |
# | 1-10                        | 1                         |
# | 0                           | 0                         |

# %% [markdown]
# # 1. Первичный анализ данных
#
# Каждый опрос, проводимый в масштабах глобальных IT-сообществ, включает в себя разнообразную информацию о профессиональных навыках, технологиях, заработной плате и образовании. Однако, как и в любом большом опросе, данные могут содержать пропущенные значения, неправильные типы данных или неоднородные данные. Для того чтобы перейти к глубокому анализу, сначала нужно убедиться, что данные подготовлены и очищены.
#
#
# **Что нужно сделать:**
#
# - Загрузи датасет
# - Используя метод .describe(), проанализируй основные числовые переменные в датасете:
#     - `ResponseID` (уникальный идентификатор респондента)
#     - `CompTotal` (размер заработной платы)
#     - `WorkExp` (количество лет профессионального опыта)
#     - `ConvertedCompYEarly` (размер заработной платы после конвертации в единую валюту).
#
# - Преобразуй вывод метода `.describe()`, чтобы данные были представлены в удобочитаемом формате без экспоненциального представления чисел.
# - Используй результаты анализа для того, чтобы лучше понять характер данных.
#
# **После проведения анализа ответь на вопросы:**
#
#
# 1. Как бы nы объяснили разницу между средним значением и медианой размера заработной платы в колонке `ConvertedCompYEarly` и в колонке `CompTotal`?
# 2. Почему среднее значение может отличаться от медианного?
# 3. Почему в некоторых переменных встречается одинаковое количество пропущенных значений? Как можно это объяснить?
# 4. Какие существуют методы для заполнения пропущенных значений в данных, и в каких случаях их можно использовать?

# %% [markdown]
# #### Оформи ответы на вопросы в этом блоке
#
# 1.
#
# 2.
#
# 3.
#
# 4.

# %% [markdown]
# ### **Критерии оценки задания:**
#
# 1. **Загрузка данных - 2 балла:**
#    - Данные успешно загружены из источника.
#    - Нет ошибок при загрузке данных.
#
# 2. **Использование метода `.describe()` - 3 балла:**
#    - Метод `.describe()` корректно применён к датасету для анализа числовых переменных.
#    - Студент объяснил и проанализировал значения, полученные из метода `.describe()`.
#
# 3. **Преобразование вывода `.describe()` - 3 балла:**
#    - Вывод метода `.describe()` преобразован для отображения числовых данных без экспоненциального формата (например, использование форматирования чисел для улучшения читаемости).
#    - Результаты представлены в удобном для восприятия виде.
#
# 4. **Ответ на вопросы анализа - 4 балла:**
#    - Разъяснена разница между средним значением и медианой для переменных `ConvertedCompYEarly` и `CompTotal`.
#    - Пояснено, почему среднее значение может отличаться от медианы, с учетом возможных выбросов или распределения данных.
#    - Дано объяснение, почему некоторые переменные имеют одинаковое количество пропущенных значений (например, зависимость между переменными или одинаковые группы респондентов).
#    - Перечислены и объяснены методы заполнения пропущенных значений (удаление строк, замена средним/медианой/модой, интерполяция и др.).
#
# 5. **Интерпретация данных и выводы - 2 балла:**
#    - Сделаны выводы на основе анализа данных, подчеркнуты ключевые особенности датасета (например, распределение зарплат, количество пропусков, важные переменные для дальнейшего анализа).
#    - Выводы логически обоснованы и связаны с результатами анализа.
#
# 6. **Дополнительные критерии (опционально, +2 балл):**
#    - Использованы дополнительные методы визуализации или анализа (например, гистограммы).
#    - Применены функции форматирования или библиотеки для улучшения представления данных.
#
# #### Максимальный балл, который можно получить за задание: **16 баллов**

# %% [markdown]
# ### Предобработка данных

# %%
import pandas as pd

# Data reading
df = pd.read_csv('data/survey_results_public.csv')
df.head(10)
# Out:
#    ResponseId     Q120                                         MainBranch  \
# 0           1  I agree                                      None of these
# 1           2  I agree                     I am a developer by profession
# 2           3  I agree                     I am a developer by profession
# 3           4  I agree                     I am a developer by profession
# 4           5  I agree                     I am a developer by profession
# 5           6  I agree                     I am a developer by profession
# 6           7  I agree                     I am a developer by profession
# 7           8  I agree                     I am a developer by profession
# 8           9  I agree  I am not primarily a developer, but I write co...
# 9          10  I agree                     I am a developer by profession
#
#                Age                                         Employment  \
# 0  18-24 years old                                                NaN
# ...

# %%
# Display the data types of each column
df.dtypes
# Out:
# ResponseId               int64
# Q120                    object
# MainBranch              object
# Age                     object
# Employment              object
#                         ...
# ProfessionalTech        object
# Industry                object
# SurveyLength            object
# SurveyEase              object
# ConvertedCompYearly    float64
# Length: 84, dtype: object

# %%
numerical_columns = ['ResponseId', 'CompTotal', 'WorkExp', 'ConvertedCompYearly']

# %%
# Display the first few rows of the selected columns
df[numerical_columns].head()
# Out:
#    ResponseId  CompTotal  WorkExp  ConvertedCompYearly
# 0           1        NaN      NaN                  NaN
# 1           2   285000.0     10.0             285000.0
# 2           3   250000.0     23.0             250000.0
# 3           4   156000.0      7.0             156000.0
# 4           5  1320000.0      6.0              23456.0

# %%
# Display the data types of the selected columns
df[numerical_columns].dtypes
# Out:
# ResponseId               int64
# CompTotal              float64
# WorkExp                float64
# ConvertedCompYearly    float64
# dtype: object

# %% [markdown]
# ### Вывод describe

# %%
# Generate the describe output for the selected columns
describe_output = df[numerical_columns].describe()

describe_output
# Out:
#          ResponseId     CompTotal       WorkExp  ConvertedCompYearly
# count  89184.000000  4.822500e+04  43579.000000         4.801900e+04
# mean   44592.500000  1.036807e+42     11.405126         1.031101e+05
# std    25745.347541  2.276847e+44      9.051989         6.814188e+05
# min        1.000000  0.000000e+00      0.000000         1.000000e+00
# 25%    22296.750000  6.300000e+04      5.000000         4.390700e+04
# 50%    44592.500000  1.150000e+05      9.000000         7.496300e+04
# 75%    66888.250000  2.300000e+05     16.000000         1.216410e+05
# max    89184.000000  5.000000e+46     50.000000         7.435143e+07

# %% [markdown]
# ### Преобразование describe для удобного чтения

# %%
# Format the describe output for better readability

def format_large_numbers(x):
    if x >= 1_000_000_000:
        return f"{x / 1_000_000_000:,.0f}B"
    elif x >= 1_000_000:
        return f"{x / 1_000_000:,.0f}M"
    elif x >= 1_000:
        return f"{x / 1_000:,.2f}K"
    else:
        return f"{x:.2f}"
    
# Convert data in columns in new format
formatted_output = describe_output.style.format(format_large_numbers)
formatted_output
# Out:
# <style type="text/css">
# </style>
# <table id="T_79340">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79340_level0_col0" class="col_heading level0 col0" >ResponseId</th>
#       <th id="T_79340_level0_col1" class="col_heading level0 col1" >CompTotal</th>
#       <th id="T_79340_level0_col2" class="col_heading level0 col2" >WorkExp</th>
#       <th id="T_79340_level0_col3" class="col_heading level0 col3" >ConvertedCompYearly</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79340_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_79340_row0_col0" class="data row0 col0" >89.18K</td>
#       <td id="T_79340_row0_col1" class="data row0 col1" >48.23K</td>
#       <td id="T_79340_row0_col2" class="data row0 col2" >43.58K</td>
#       <td id="T_79340_row0_col3" class="data row0 col3" >48.02K</td>
#     </tr>
#     <tr>
#       <th id="T_79340_level0_row1" class="row_heading level0 row1" >mean</th>
# ...

# %%
# Count NaN values in each column

nan_counts = df[numerical_columns].isnull().sum()
nan_counts
# Out:
# ResponseId                 0
# CompTotal              40959
# WorkExp                45605
# ConvertedCompYearly    41165
# dtype: int64

# %% [markdown]
# #### Дополнительные графики для анализа

# %%
import matplotlib.pyplot as plt


# Box plot 'ConvertedCompYearly'
plt.figure(figsize=(10, 6))
boxplot = df[df['ConvertedCompYearly'] < 500_000].boxplot(column='ConvertedCompYearly')
plt.title('Box Plot of ConvertedCompYearly')
plt.ylabel('ConvertedCompYearly')
plt.show()
# Out:
# Text(0, 0.5, 'ConvertedCompYearly')

# %% [markdown]
# ### Анализ и ответы на вопросы
#
# #### Общий анализ данных
#
# **В целом дано:**
# - Датасет содержит информацию о различных аспектах профессиональной деятельности разработчиков, таких как уровень образования, опыт работы, технологии и заработная плата.
# - Основные числовые переменные в датасете включают `ResponseId`, `CompTotal`, `WorkExp` и `ConvertedCompYearly`.
# - Переменная `ResponseId` представляет собой уникальный идентификатор респондента, `CompTotal` - размер заработной платы, `WorkExp` - количество лет профессионального опыта, а `ConvertedCompYearly` - размер заработной платы после конвертации в единую валюту.
#
# **Можно сказать на основе таблицы:**
# - Опрошенных около 81 тысячи.
# - Средний размер заработной платы (`ConvertedCompYearly`) составляет около 103K (103 тысячи) единиц валюты в год.
# - STD больше 680K, что говорит о большом разбросе в заработной плате.
# - Около 75% опрошенных в IT уже более 5 лет.
# - Зарплаты в волюте страны сильно отличаются от зарплаты в единой валюте. Это связано с разностью курсов валют и уровнем жизни в разных странах.
# - В опросе принимали участие также люди с опытом работы меньше года.
# - В данных есть пропущенные значения в переменных `CompTotal` и `ConvertedCompYearly`.
# - Пропущенные значения в `CompTotal` и `ConvertedCompYearly` могут быть связаны с тем, что респонденты не указали свою заработную плату или данные были недоступны.
# - Пропущенные значения в `WorkExp` могут быть связаны с тем, что респонденты не указали свой опыт работы или данные были недоступны.
#
# #### Ответы на вопросы
#
# 1. **Как бы ты объяснил разницу между средним значением и медианой размера заработной платы в колонке `ConvertedCompYEarly` и в колонке `CompTotal`?**
#
# Разницу можно объяснить тем, что среднее значение размера заработной платы (`ConvertedCompYEarly` и `CompTotal`) рассчитывается как сумма всех значений, деленная на количество наблюдений. Среднее значение чувствительно к выбросам и аномалиям в данных, что может привести к искажению результатов. Медиана, в свою очередь, представляет собой значение, которое делит упорядоченный набор данных на две равные части. Медиана менее чувствительна к выбросам и аномалиям, поэтому она может быть более репрезентативной мерой центральной тенденции для данных с асимметричным распределением.
#
# 2. **Почему среднее значение может отличаться от медианного?**
#
# Среднее значение и медиана могут отличаться из-за наличия выбросов или асимметрии в распределении данных. Если данные содержат аномально высокие или низкие значения, среднее значение будет сильно искажено, в то время как медиана останется более стабильной мерой центральной тенденции.
#
# 3. **Почему в некоторых переменных встречается одинаковое количество пропущенных значений? Как можно это объяснить?**
#
# Одинаковое количество пропущенных значений в разных переменных может быть связано с тем, что респонденты не заполнили определенные вопросы или пропустили их. Это может быть связано с тем, что некоторые вопросы могут быть необязательными или не относиться к конкретному респонденту. Также пропуски могут возникнуть из-за ошибок в данных или технических проблем при сборе информации.
#
# 4. **Какие существуют методы для заполнения пропущенных значений в данных, и в каких случаях их можно использовать?**
#
# Существует несколько методов для заполнения пропущенных значений в данных:
# - **Замена на среднее, медиану или моду.** Этот метод подходит для числовых переменных и может быть использован, если пропусков немного и они случайны.
# - **Интерполяция.**
# Она бывает линейная, геометрическая или кубическая. Хорошо подходит для временных рядов или последовательных данных.
# - **Замена на константу.** Можно заменить пропущенные значения на константу, если они несущественны для анализа, например на 0. Или же если мы подразумеваем какое-либо значение по умолчанию.
# - Удаление строк или столбцов с пропущенными значениями (если пропусков немного).
# - **Использование алгоритмов машинного обучения.** Для заполнения пропусков можно использовать ИИ, кластеризацию по свойствам и присвоение среднего для каждой группы/кластера.
# - Темп роста к следующему или предыдущему периоду.
# - Иногда можно восстановить данные на основе других свойств объекта, если они зависимы друг от друга.
# - Использование дополнительных внешних данных для заполнения пропусков
#
# Есть также и другие способы в зависимости от специфики данных и задачи.

# %% [markdown]
# # 2. Визуализация пропущенных значений
#
# Пропущенные значения могут серьёзно повлиять на качество анализа и точность выводов, особенно в таких критически важных показателях, как заработная плата, опыт работы или технологические предпочтения. Чтобы эффективно работать с пропусками, важно не только видеть статистику, но и визуализировать их распределение. Это поможет понять, насколько сильно они влияют на результаты анализа и какие переменные больше всего подвержены проблемам с данными.
#
# **Что необходимо сделать:**
# - Изучи возможности библиотек `seaborn` и `missingno` для анализа пропущенных значений в датасете.
# - Построй график, который наглядно покажет распределение пропущенных значений в датасете.
# - Проанализируй полученный график и сделайте выводы о масштабах проблемы пропусков.

# %% [markdown]
# ### **Критерии оценки задания:**
#
# 1. **Изучение библиотек для анализа пропущенных значений - 2 балла:**
#    - Применены соответствующие функции для анализа пропусков.
#    - Использование библиотеки соответствует цели анализа — наглядное отображение пропусков в данных.
#
# 2. **Построение графика пропусков - 5 баллов:**
#    - Построен график, который корректно визуализирует пропущенные значения в датасете.
#    - График отражает полную картину распределения пропусков по переменным, позволяя выявить наиболее проблемные столбцы.
#    - График правильно оформлен: подписаны оси, добавлены заголовки, а если использована цветовая схема, она интуитивно понятна.
#
# 3. **Анализ и выводы на основе визуализации - 4 балла:**
#    - Проанализирован график и описано, какие переменные больше всего подвержены пропускам.
#    - Сделаны выводы о масштабе проблемы пропусков и их возможном влиянии на дальнейший анализ данных.
#    - Указано, как пропуски могут исказить результаты анализа, если их не обработать.
#
# 4. **Дополнительный анализ и предложения по обработке пропусков - 2 балла:**
#    - Предложены возможные методы обработки пропущенных данных на основе визуализации (например, удаление, заполнение или игнорирование).
#    - Описаны возможные последствия для анализа в зависимости от выбранной стратегии обработки.
#
# 5. **Дополнительные критерии (опционально, +2 балл):**
#    - Использование нескольких типов графиков для сравнения пропусков.
#    - Применены нестандартные методы визуализации или комбинирование инструментов.
#
# #### Максимальный балл, который можно получить за задание: **16 баллов**

# %% [markdown]
# # 3. Анализ способов изучения программирования
#
# Люди учатся программировать разными способами: кто-то получает формальное образование в школах и университетах, а кто-то учится самостоятельно. Для компаний и образовательных учреждений важно понимать, как различные способы обучения влияют на карьерные перспективы и уровень зарплат. Этот анализ поможет выявить различия между теми, кто учился программировать в учебных заведениях, и теми, кто обучался другим способом.
#
# **Что нужно сделать:**
#
# - Напиши функцию, которая преобразует данные в переменной `'LearnCode'` и разделит людей на две группы: те, кто учился программированию в школе или университете, и те, кто учился другими способами. В результате должна получиться новая переменная `'LearnCodeInSchool'` с двумя типами значений: `'Yes'` (учился в школе/университете) и `'No'` (учился другим способом).
# - Построй график, сравнивающий людей, которые учились программированию в школе/университете, с теми, кто учился самостоятельно, в разрезе групп по типу занятости (переменная `'RemoteWork'`).
# - Построй график зависимости размера заработной платы (`'ConvertedCompYearly'`) от опыта работы (`'YearsCodePro'`). Для этого сначала нужно преобразовать данные в этой переменной (заменить строковые значения).
# - Посчитай коэффициент корреляции между опытом работы и размером заработной платы.

# %% [markdown]
# ### **Критерии оценки:**
#
# 1. **Создание функции для преобразования данных - 5 баллов:**
#    - Написана корректная функция, которая преобразует данные и разделяет их на две группы: те, кто учился программированию в школе или университете, и те, кто обучался другими способами.
#    - Создана новая переменная с двумя типами значений: `'Yes'` (учился в школе/университете) и `'No'` (учился другим способом).
#    - Функция корректно обработала все значения, включая случаи с множественным выбором.
#
# 2. **Построение графика сравнения по типу занятости - 3 балла:**
#    - Построен график, который корректно сравнивает людей, учившихся программированию в школе/университете и самостоятельно, по переменной `'RemoteWork'`.
#    - График наглядный и имеет подписи к осям, заголовки, а также корректную цветовую схему (если применимо).
#    - Использован метод `.groupby()` или другой соответствующий метод для группировки данных.
#
# 3. **Построение графика зависимости заработной платы от опыта работы - 3 балла:**
#    - Построен график зависимости размера заработной платы (`'ConvertedCompYearly'`) от опыта работы (`'YearsCodePro'`).
#    - Данные в переменной `'YearsCodePro'` были корректно преобразованы (например, строковые значения заменены на числовые).
#    - График оформлен правильно, с подписями осей, заголовками и чётким отображением зависимости.
#
# 4. **Расчёт коэффициента корреляции - 2 балла:**
#    - Коэффициент корреляции между опытом работы и размером заработной платы был корректно рассчитан.
#    - Студент объяснил полученный результат и сделал вывод о том, есть ли значимая связь между этими переменными.
#    - Использованы соответствующие методы расчёта корреляции (например, `corr()` или другой статистический метод).
#
# 5. **Анализ и выводы - 2 балла:**
#    - Студент проанализировал результаты, сделав выводы о различиях между группами по типу обучения и по уровню зарплаты в зависимости от опыта.
#    - Сделаны обоснованные выводы о том, как обучение программированию и опыт работы влияют на зарплаты и тип занятости (удалённая работа и др.).
#    - Выводы логически связаны с визуализациями и рассчитанными метриками.
#
# 6. **Дополнительные критерии (опционально, +1 балл):**
#   - Использование дополнительных визуализаций или методов для улучшения анализа.
#   - Применение продвинутых методов визуализации для более глубокой интерпретации данных.
#
# #### Максимальный балл, который можно получить за задание: **16 баллов**

# %% [markdown]
# # 4. Анализ уровня образования и заработной платы в разных странах
#
# Уровень образования и опыт работы являются важными факторами, которые могут влиять на карьерные успехи и размер заработной платы программистов. В разных странах эти факторы могут оказывать разное влияние в зависимости от экономических и социальных условий. Для компаний, которые нанимают специалистов в международном контексте, важно понимать, как эти параметры различаются по странам. Анализ поможет выявить ключевые различия в образовании и зарплатах между странами и возрастными группами.
#
# **Что нужно сделать:**
#
# - Построй график распределения уровня образования программистов (`'EdLevel'`) в топ-10 стран (по количеству респондентов). Этот график поможет понять, как уровень образования варьируется в разных странах.
# - Построй график зависимости заработной платы от опыта работы в этих топ-10 странах. Для этого используй график из предыдущего задания и адаптируй его для отображения данных по странам.
# - Построй график распределения заработной платы в разных возрастных группах (`'Age'`). Для более удобного отображения данных изучи метод построения графиков с использованием [`'FacetGrid'`](https://seaborn.pydata.org/generated/seaborn.FacetGrid.html).

# %% [markdown]
# ### **Критерии оценки:**
#
# 1. **Построение графика распределения уровня образования - 5 баллов:**
#    - Построен корректный график, отображающий распределение уровня образования программистов в топ-10 странах.
#    - График позволяет увидеть различия в уровне образования между странами.
#    - График оформлен корретно: добавлены заголовки, подписи осей, легенда и, при необходимости, цветовая схема для наглядности. Все подписи осей - читаемые.
#    - Использованы подходящие инструменты для работы с категориями и группировками данных.
#
# 2. **Построение графика зависимости заработной платы от опыта работы - 5 баллов:**
#    - Построен график зависимости заработной платы от опыта работы в топ-10 странах.
#    - График наглядно отображает зависимости между зарплатой и опытом, а также различия между странами.
#    - Правильно адаптированы данные из предыдущего задания для отображения этой зависимости по странам.
#    - График оформлен корректно, с подписями осей, заголовками и добавленной легендой для стран.
#
# 3. **Построение графика распределения заработной платы в возрастных группах - 3 балла:**
#    - Построен график, отображающий распределение заработной платы в разных возрастных группах.
#    - Использован метод `FacetGrid` или другой подходящий метод для отображения данных по возрастным категориям.
#    - График позволяет сравнить распределение зарплат в различных возрастных группах и выявить важные тренды.
#    - Исправлены возможные проблемы с осью y, как указано в задании.
#
# 4. **Анализ и выводы - 2 балла:**
#    - Проанализированф результаты графиков, сделаны выводы о том, как уровень образования и опыт работы влияют на зарплаты программистов в разных странах.
#    - Выявлены различия между странами и возрастными группами, с объяснением возможных причин этих различий.
#    - Выводы логически обоснованы и подкреплены результатами визуализации данных.
#
# 5. **Дополнительные критерии (опционально, +1 балл):**
#   - Использование дополнительных методов анализа или графиков для более глубокого изучения данных.
#   - Применение других методов визуализации для улучшения представления данных.
#
#
# #### Максимальный балл, который можно получить за задание: **16 баллов**

# %% [markdown]
# # 5. Анализ изменения уровня заработной платы после пандемии
#
# Пандемия COVID-19 оказала огромное влияние на глобальный рынок труда, и IT-индустрия не стала исключением. Во многих странах зарплаты разработчиков могли измениться в зависимости от экономической ситуации и условий удаленной работы. Для компаний, работающих в международном контексте, важно понимать, как изменился уровень зарплат в различных странах после пандемии, чтобы принимать обоснованные решения по найму и компенсациям. Анализ данных за последние пять лет поможет выявить эти изменения и дать ответ на вопрос о том, как пандемия повлияла на IT-сектор.
#
# **Что нудно сделать**:
#
# - Загрузи датасеты за последние пять лет (с 2019 по 2023 год), содержащие данные о зарплатах разработчиков.
#
# - Для каждой страны, которую ты выберешь для анализа (5 стран), посчитай медианный уровень заработной платы по годам.
#
# - Объедини данные по странам и годам в один датафрейм, который должен содержать три колонки: `Year`, `Country`, `MedianSalary`.
#
# - Построй графики, показывающие изменения средней заработной платы разработчиков в этих странах за последние пять лет.
#
# **Обрати внимание:**
#
# При загрузке датасета за 2019 год может возникнуть ошибка ParserError: Error tokenizing data, указывающая на неправильный формат данных в CSV-файле. Вы можешь повторно загрузить данные или использовать блок try-except для обработки ошибки.
#
# *Дополнительное задание:*
#
# Подумай, как можно автоматизировать процесс загрузки и обработки всех датасетов, чтобы не делать это вручную для каждого года. Попробуй создать функцию, которая будет автоматически выполнять все шаги для всех выбранных стран и датасетов.

# %% [markdown]
# ### **Критерии оценки:**
#
# 1. **Загрузка и обработка данных за последние пять лет - 5 баллов:**
#    - Данные за 2019–2023 годы успешно загружены, включая корректную обработку возможных ошибок при загрузке.
#    - Данные содержат информацию о зарплатах разработчиков для выбранных 5 стран.
#    - Все данные о зарплатах правильно загружены и обработаны.
#
# 2. **Расчет медианного уровня заработной платы по годам и странам - 4 балла:**
#    - Для каждой выбранной страны корректно рассчитан медианный уровень заработной платы по каждому году.
#    - Полученные медианные значения собраны в один датафрейм с обозначенными колонками.
#    - Данные правильно сгруппированы по годам и странам для дальнейшего анализа.
#
# 3. **Построение графиков изменения заработной платы - 5 баллов:**
#    - Построены графики, отображающие изменения медианной заработной платы разработчиков в выбранных странах за последние пять лет.
#    - Графики позволяют четко увидеть тенденции роста или падения зарплат в каждой стране.
#    - Графики правильно оформлены: добавлены заголовки, подписи осей и легенда для обозначения стран.
#
# 4. **Анализ и выводы - 3 балла:**
#    - Сделаны выводы о том, как пандемия COVID-19 повлияла на уровень заработных плат разработчиков в разных странах.
#    - Обоснованы возможные причины изменения зарплат в зависимости от экономической ситуации или условий удаленной работы в каждой стране.
#    - Выводы логически связаны с данными, представленными на графиках.
#
# 5. **Автоматизация процесса (дополнительно, +2 балла):**
#   - Предложен или реализован способ автоматизации загрузки и обработки данных для нескольких стран и лет, что облегчает процесс анализа.
#
# 6. **Дополнительные критерии (опционально, +1 балл):**
#   - Использованы дополнительные методы анализа или продвинутые визуализации для более глубокого изучения данных.
#
# #### Максимальный балл, который можно получить за задание: **20 баллов**

# %% [markdown]
# # 6. Интерпретация данных и формулирование гипотез
#
# После проведения анализа и построения графиков важно сделать выводы и сформулировать гипотезы, которые можно проверить в дальнейшем. Это поможет как специалистам, так и компаниям лучше понять тенденции, влияющие на зарплаты и карьерные пути разработчиков. На основе визуализаций можно выдвигать гипотезы о возможных причинах тех или иных наблюдаемых тенденций, а также предлагать дополнительные переменные для углубленного анализа.
#
# **Что нужно сделать:**
#
# - Проанализируй результаты построенных графиков и данных.
# - Сформулируй гипотезы, основываясь на визуализированных данных. Например, как определенные переменные (возраст, опыт работы, образование, место работы) могут влиять на размер заработной платы или карьерные предпочтения разработчиков.
# - Подумай, какие дополнительные переменные можно бы использовать для дальнейшего анализа. Почему эти переменные могут быть важны для проверки гипотез или выявления новых закономерностей?

# %% [markdown]
# #### Результаты анализа оформи в этом блоке

# %% [markdown]
# ### **Критерии оценки:**
#
# 1. **Анализ результатов построенных графиков и данных - 5 баллов:**
#    - Сделаны выводы о тенденциях, выявленных в данных (например, влияние возраста, опыта работы, уровня образования на заработные платы).
#    - Анализ логично связан с визуализациями и поддержан фактическими данными.
#
# 2. **Формулирование гипотез - 6 баллов:**
#    - Сформулированы минимум две-три чёткие и проверяемые гипотезы, основанные на визуализированных данных.
#    - Каждая гипотеза имеет логическое обоснование на основе анализа данных и графиков.
#    - Гипотезы касаются важных переменных, таких как возраст, опыт работы, образование, место работы и их возможное влияние на зарплату или карьерные пути.
#
# 3. **Предложение дополнительных переменных для анализа - 3 балла:**
#    - Студент предложил дополнительные переменные, которые могут быть полезны для дальнейшего анализа (например, тип компании, размер команды, регион).
#    - Логически обосновано, почему эти переменные важны для проверки гипотез или выявления новых закономерностей.
#    - Дополнительные переменные могут улучшить глубину анализа и дать более точные результаты.
#
# 4. **Обоснование предложений и выводов - 2 балла:**
#    - Все предложенные гипотезы и переменные чётко обоснованы, с использованием данных из предыдущего анализа.
#    - Выводы логично вытекают из анализа и визуализаций.
#
# 5. **Дополнительные критерии (опционально, +1 балл):**
#    - Преложен способ проверки гипотез (например, использование статистических тестов или дополнительных экспериментов).
#    - Предложены нестандартные переменные для анализа или интересные идеи для проверки, основанные на глубоком понимании данных и контекста.
#
# #### Максимальный балл, который можно получить за задание: **16 баллов**
